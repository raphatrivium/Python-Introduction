# %% [markdown]
# <a href="https://colab.research.google.com/github/raphatrivium/Python-Introduction/blob/main/raphael_aula7_parte2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercícios
# https://penseallen.github.io/PensePython2e/05-cond-recur.html
#
# 1. O módulo time fornece uma função, também chamada time, que devolve a Hora Média de Greenwich na “época”, que é um momento arbitrário usado como ponto de referência. Em sistemas UNIX, a época é primeiro de janeiro de 1970.

# %%
import time
time.time()
# Out:
# 1603282575.16472

# %% [markdown]
# Escreva um script que leia a hora atual e a converta em um tempo em horas, minutos e segundos, mais o número de dias desde a época.

# %%
import datetime
import time
#hora atual
datetime.datetime.fromtimestamp(time.time()).strftime('%d/%m/%Y %H:%M:%S')
# Out:
# '21/10/2020 12:17:28'

# %% [markdown]
# 2. O último teorema de Fermat diz que não existem números inteiros a, b e c tais que `a**n + b**n == c**n` para quaisquer valores de n maiores que 2.
#    1. Escreva uma função chamada `check_fermat` que receba quatro parâmetros – a, b, c e n – e verifique se o teorema de Fermat se mantém. Se n for maior que 2 e `a**n + b**n == c**n` o programa deve imprimir, “Holy smokes, Fermat was wrong!” Senão o programa deve exibir “No, that doesn’t work.”
#    1. Escreva uma função que peça ao usuário para digitar valores para a, b, c e n, os converta em números inteiros e use `check_fermat` para verificar se violam o teorema de Fermat.

# %%
def check_fermat(a, b, c, n):
    #Filtra o teorema
    if (n <= 2):
        print('O valor de n tem que ser maior que 2 (n > 2) :P')
        return
    #Verificar o teorema
    if (a**n + b**n == c**n):
        print('Holy smokes, Fermat was wrong!')
        return True
    else:
        print('No, that doesn’t work.')
        return False

#Inserindo valores
print('Insira os a,b,c (inteiros) e n para teste de Fermat [a**n + b**n == c**n]')
a = int(input('a: '))
b = int(input('b: '))
c = int(input('c: '))
n = int(input('n: '))

check_fermat(a, b, c, n)

# %%
#V2 Duvida!
def check_fermat(a, b, c, n):
    if (n <= 2):
        print('O valor de n tem que ser maior que 2 (n > 2) :P')
        return
    #Verificar o teorema
    if (a**n + b**n == c**n):
        print('Holy smokes, Fermat was wrong!')
        return True
    else:
        print('No, that doesn’t work.')
        return False
#Inserindo valores
print('Insira os a,b,c (inteiros) e n para teste de Fermat [a**n + b**n == c**n]')
tipo_inteiro = type(1)
a = input('a: ')
b = input('b: ')
c = input('c: ')
n = input('n: ')

entries = [a, b, c, n]
for i in entries:
  if type(i) != tipo_inteiro:
    print('Error: ',i,' is not a integer')
    break

a = int(a)
b = int(b)
c = int(c)
n = int(n)
check_fermat(a, b, c, n)

# %% [markdown]
# 3. Há um teste simples para ver se é possível formar um triângulo para quaisquer três comprimentos: Se algum dos três comprimentos for maior que a soma dos outros dois, então você não pode formar um triângulo. Senão, você pode. (Se a soma de dois comprimentos igualar o terceiro, eles formam um triângulo chamado “degenerado”.)
#    1. Escreva uma função chamada `is_triangle` que receba três números inteiros como argumentos, e que imprima “Yes” ou “No”, dependendo da possibilidade de formar ou não um triângulo de gravetos com os comprimentos dados.
#    1. Escreva uma função que peça ao usuário para digitar três comprimentos de gravetos, os converta em números inteiros e use `is_triangle` para verificar se os gravetos com os comprimentos dados podem formar um triângulo.

# %%
def is_triangle(a, b, c):
    triangle = True
    #Testes para verificar se são triângulos
    if (a + b < c or b + c < a or c + a < b):
        triangle = False
    #Retorna o resultado
    if (triangle):
        print('Este triângulo existe')
    else:
        print('Este triângulo não existe')
    return triangle
#Inserindo valores
print('Digite o comprimento dos lados a,b e c de um triângulo.')
a = int(input('a: '))
b = int(input('b: '))
c = int(input('c: '))
is_triangle(a, b, c)
# Out:
# Digite o comprimento dos lados a,b e c de um triângulo.
# a: 2
# b: 4
# c: 5
# Este triângulo existe
# True

# %% [markdown]
# 4. Leia a próxima função e veja se consegue compreender o que ela faz (veja os exemplos no Capítulo 4). Então execute-a e veja se acertou.

# %%
# Instala e importa o ColabTurtle
# !pip3 install ColabTurtle
import ColabTurtle
import ColabTurtle.Turtle
#------------------------------------------
def draw(t, length, n):
    if n == 0:
        return
    angle = 50
    t.forward(length * n)
    t.left(angle)
    draw(t, length, n-1)
    t.right(2 * angle)
    draw(t, length, n-1)
    t.left(angle)
    t.backward(length * n)
#------------------------------------------
alice = ColabTurtle.Turtle
alice.initializeTurtle()
alice.speed(10)
draw(alice, 10, 5)
# Out:
# Requirement already satisfied: ColabTurtle in /usr/local/lib/python3.6/dist-packages (2.0.0)
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="369.3582222752409" y2="174.28849561253844" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="369.3582222752409" y1="174.28849561253844" x2="339.8139896848747" y2="179.49794094254634" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="339.8139896848747" y1="179.49794094254634" x2="329.8139896848747" y2="196.8184490182351" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="329.8139896848747" y1="196.8184490182351" x2="333.2341911181314" y2="206.21537522609418" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="333.2341911181314" y1="206.21537522609418" x2="329.8139896848747" y2="196.8184490182351" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="329.8139896848747" y1="196.8184490182351" x2="319.96591215475263" y2="198.5549307949044" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="319.96591215475263" y1="198.5549307949044" x2="329.8139896848747" y2="196.8184490182351" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="329.8139896848747" y1="196.8184490182351" x2="339.8139896848747" y2="179.49794094254634" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="339.8139896848747" y1="179.49794094254634" x2="324.49310082249514" y2="166.64218874881556" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="324.49310082249514" y1="166.64218874881556" x2="314.6450232923731" y2="168.37867052548486" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="314.6450232923731" y1="168.37867052548486" x2="324.49310082249514" y2="166.64218874881556" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="324.49310082249514" y1="166.64218874881556" x2="324.49310082249514" y2="156.64218874881556" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="324.49310082249514" y1="156.64218874881556" x2="324.49310082249514" y2="166.64218874881556" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="324.49310082249514" y1="166.64218874881556" x2="339.8139896848747" y2="179.49794094254634" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="339.8139896848747" y1="179.49794094254634" x2="369.3582222752409" y2="174.28849561253844" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="369.3582222752409" y1="174.28849561253844" x2="369.3582222752409" y2="144.28849561253844" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="369.3582222752409" y1="144.28849561253844" x2="354.03733341286136" y2="131.43274341880766" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="354.03733341286136" y1="131.43274341880766" x2="344.1892558827393" y2="133.16922519547697" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="344.1892558827393" y1="133.16922519547697" x2="354.03733341286136" y2="131.43274341880766" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="354.03733341286136" y1="131.43274341880766" x2="354.03733341286136" y2="121.43274341880766" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="354.03733341286136" y1="121.43274341880766" x2="354.03733341286136" y2="131.43274341880766" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="354.03733341286136" y1="131.43274341880766" x2="369.3582222752409" y2="144.28849561253844" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="369.3582222752409" y1="144.28849561253844" x2="384.67911113762045" y2="131.43274341880766" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.67911113762045" y1="131.43274341880766" x2="384.67911113762045" y2="121.43274341880766" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="384.67911113762045" y1="121.43274341880766" x2=" ...

# %% [markdown]
# A curva de Koch é um fractal que parece com o da Figura abaixo.
# ![](https://github.com/PenseAllen/PensePython2e/raw/master/fig/tnkp_0502.png)
#
# Para desenhar uma curva de Koch com o comprimento x, tudo o que você tem que fazer é:
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 1. Vire 60 graus à esquerda.
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 1. Vire 120 graus à direita.
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 1. Vire 60 graus à esquerda.
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
#
# A exceção é se x for menor que 3: neste caso, você pode desenhar apenas uma linha reta com o comprimento x.
#
# 1. Escreva uma função chamada `koch` que receba um `ColabTurtle` (ou turtle) e um comprimento como parâmetros, e use o `ColabTurtle` para desenhar uma curva de Koch com o comprimento dado.
#
# 1. Escreva uma função chamada `snowflake` que desenhe três curvas de Koch para fazer o traçado de um floco de neve.
#
# 1. A curva de Koch pode ser generalizada de vários modos. Veja exemplos em http://en.wikipedia.org/wiki/Koch_snowflake e implemente o seu favorito.

# %%
import ColabTurtle.Turtle
#---------------------------------------
def koch(turtle, length):
    if length >= 3:
        koch(turtle, length/3)
        turtle.left(60)
        koch(turtle, length/3)
        turtle.right(120)
        koch(turtle, length/3)
        turtle.left(60)
        koch(turtle, length/3)
    else:
        turtle.forward(int(length))
#---------------------------------------
def snowflake(turtle, length):
    koch(turtle, length)
    turtle.right(120)
    koch(turtle, length)
    turtle.right(120)
    koch(turtle, length)
#---------------------------------------
alice = ColabTurtle.Turtle
alice.initializeTurtle()
alice.speed(10)
snowflake(alice, 250)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="249.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="249.0" x2="399.1339745962156" y2="248.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="399.1339745962156" y1="248.5" x2="400.0" y2="248.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="248.0" x2="400.0" y2="247.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="247.0" x2="399.1339745962156" y2="246.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="399.1339745962156" y1="246.5" x2="398.26794919243116" y2="247.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="398.26794919243116" y1="247.0" x2="398.26794919243116" y2="246.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="398.26794919243116" y1="246.0" x2="397.40192378864674" y2="245.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.40192378864674" y1="245.5" x2="398.26794919243116" y2="245.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="398.26794919243116" y1="245.0" x2="398.26794919243116" y2="244.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="398.26794919243116" y1="244.0" x2="399.1339745962156" y2="244.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="399.1339745962156" y1="244.5" x2="400.0" y2="244.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="244.0" x2="400.0" y2="243.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="243.0" x2="399.1339745962156" y2="242.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="399.1339745962156" y1="242.5" x2="400.0" y2="242.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="242.0" x2="400.0" y2="241.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="241.0" x2="399.1339745962156" y2="240.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="399.1339745962156" y1="240.5" x2="398.26794919243116" y2="241.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="398.26794919243116" y1="241.0" x2="398.26794919243116" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="398.26794919243116" y1="240.0" x2="397.40192378864674" y2="239.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="397.40192378864674" y1="239.5" x2="396.5358983848623" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="396.5358983848623" y1="240.0" x2="396.5358983848623" y2="241.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="396.5358983848623" y1="241.0" x2="395.6698729810779" y2="240.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="395.6698729810779" y1="240.5" x2="394.8038475772935" y2="241.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="394.8038475772935" y1="241.0" x2="394.8038475772935" y2="240.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="394.8038475772935" y1="240.0" x2="393.93782217350906" y2="239.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="393.93782217350906" y1="239.5" x2="394.8038475772935" y2="239.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="394.8038475772935" y1="239.0" x2="394.8038475772935" y2="238.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="394.8038475772935" y1="238.0" x2="393.93782217350906" y2="237.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="393.93782217350906" y1="237.5" x2="393.07179676972464" y2="238.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="393.07179676972464" y1="238.0" x2="393.07179676972464" y2="237.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/ ...
