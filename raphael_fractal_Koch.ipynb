# %% [markdown]
# <a href="https://colab.research.google.com/github/raphatrivium/Python-Introduction/blob/main/raphael_fractal_Koch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A curva de Koch é um fractal que parece com o da Figura abaixo.
# ![](https://github.com/PenseAllen/PensePython2e/raw/master/fig/tnkp_0502.png)
#
# Para desenhar uma curva de Koch com o comprimento x, tudo o que você tem que fazer é:
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 1. Vire 60 graus à esquerda.
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 1. Vire 120 graus à direita.
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 1. Vire 60 graus à esquerda.
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
#
# A exceção é se x for menor que 3: neste caso, você pode desenhar apenas uma linha reta com o comprimento x.
#
# 1. Escreva uma função chamada `koch` que receba um `ColabTurtle` (ou turtle) e um comprimento como parâmetros, e use o `ColabTurtle` para desenhar uma curva de Koch com o comprimento dado.
#
# 1. Escreva uma função chamada `snowflake` que desenhe três curvas de Koch para fazer o traçado de um floco de neve.
#
# 1. A curva de Koch pode ser generalizada de vários modos. Veja exemplos em http://en.wikipedia.org/wiki/Koch_snowflake e implemente o seu favorito.

# %%
# Instala e importa o ColabTurtle
# !pip3 install ColabTurtle
import ColabTurtle
import ColabTurtle.Turtle
# Out:
# Requirement already satisfied: ColabTurtle in /usr/local/lib/python3.6/dist-packages (2.0.0)

# %%
def koch(turtle, length):
    if length >= 3:
        koch(turtle, length/3)
        turtle.left(60)
        koch(turtle, length/3)
        turtle.right(120)
        koch(turtle, length/3)
        turtle.left(60)
        koch(turtle, length/3)
    else:
        turtle.forward(int(length))
#---------------------------------------
def snowflake(turtle, length):
    koch(turtle, length)
    turtle.right(120)
    koch(turtle, length)
    turtle.right(120)
    koch(turtle, length)
#---------------------------------------
alice = ColabTurtle.Turtle
alice.initializeTurtle()
alice.speed(10)
alice.penup()
alice.goto(200,400)
#alice.backward(200)
alice.pendown()
snowflake(alice, 250)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="200" y1="400" x2="200.0" y2="399.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="399.0" x2="199.13397459621555" y2="398.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.13397459621555" y1="398.5" x2="200.0" y2="398.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="398.0" x2="200.0" y2="397.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="397.0" x2="199.13397459621555" y2="396.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.13397459621555" y1="396.5" x2="198.2679491924311" y2="397.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="198.2679491924311" y1="397.0" x2="198.2679491924311" y2="396.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="198.2679491924311" y1="396.0" x2="197.40192378864666" y2="395.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="197.40192378864666" y1="395.5" x2="198.2679491924311" y2="395.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="198.2679491924311" y1="395.0" x2="198.2679491924311" y2="394.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="198.2679491924311" y1="394.0" x2="199.13397459621555" y2="394.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.13397459621555" y1="394.5" x2="200.0" y2="394.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="394.0" x2="200.0" y2="393.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="393.0" x2="199.13397459621555" y2="392.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.13397459621555" y1="392.5" x2="200.0" y2="392.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="392.0" x2="200.0" y2="391.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="200.0" y1="391.0" x2="199.13397459621555" y2="390.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="199.13397459621555" y1="390.5" x2="198.2679491924311" y2="391.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="198.2679491924311" y1="391.0" x2="198.2679491924311" y2="390.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="198.2679491924311" y1="390.0" x2="197.40192378864666" y2="389.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="197.40192378864666" y1="389.5" x2="196.5358983848622" y2="390.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="196.5358983848622" y1="390.0" x2="196.5358983848622" y2="391.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="196.5358983848622" y1="391.0" x2="195.66987298107776" y2="390.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="195.66987298107776" y1="390.5" x2="194.8038475772933" y2="391.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="194.8038475772933" y1="391.0" x2="194.8038475772933" y2="390.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="194.8038475772933" y1="390.0" x2="193.93782217350886" y2="389.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="193.93782217350886" y1="389.5" x2="194.8038475772933" y2="389.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="194.8038475772933" y1="389.0" x2="194.8038475772933" y2="388.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="194.8038475772933" y1="388.0" x2="193.93782217350886" y2="387.5" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="193.93782217350886" y1="387.5" x2="193.07179676972441" y2="388.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="193.07179676972441" y1="388.0" x2="193.07179676972441" y2="387.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/ ...
# Buffered data was truncated after reaching the output size limit.
